# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# @Time    : 23/10/2021 12:00 PM
# @Author  : Scott
# @Main    : Zheng@utk.edu
# @File    : GACM_ProductionByEle.py
# @Software: PyCharm
# @Notes   : Transfer the GCAM output data to input of SYBmodel

import pandas as pd

# %%
EleAndBasin = pd.read_csv('data10top_converted_waterbasin.csv',usecols=['Name','BasinName'])
Basins = EleAndBasin.BasinName.unique()
EleAndBasin
# Out:
#                                          Name          BasinName
# 0                             Agency Rail LLC   OilCrop_MissppRN
# 1                         Airial Construction   OilCrop_MissppRN
# 2    Alliance Builders And Construction, Inc.   OilCrop_MissppRN
# 3                      Artix Construction Inc   OilCrop_MissppRN
# 4                Assumption Cooperative Grain   OilCrop_MissppRN
# ..                                        ...                ...
# 222                   Dakota Plains AG Center  OilCrop_MissouriR
# 223              Farmers Cooperative Elevator   OilCrop_MissppRN
# 224                      Harrold Grain Co LLC  OilCrop_MissouriR
# 225          Madison Farmers Elevator Company  OilCrop_MissouriR
# 226                Southeast Farmers Elevator  OilCrop_MissouriR
#
# [227 rows x 2 columns]

# %%
ProductByBasin = pd.read_excel('GCAM outputs_20210910.xlsx', sheet_name=0,index_col=0, usecols='D,F,G:AB')  # pandas >1.3 if engine=None default to engine='openpyxl'
ProductByBasin
# Out:
#                                      Scenario      1990      2005      2010  \
# BasinName
# OilCrop_ArkWhtRedR  OilCrop_ArkWhtRedR_IRR_hi  0.284815  0.427582  0.463761
# OilCrop_ArkWhtRedR  OilCrop_ArkWhtRedR_IRR_lo  0.189877  0.285054  0.309174
# OilCrop_ArkWhtRedR  OilCrop_ArkWhtRedR_RFD_hi  0.630091  0.945929  1.025970
# OilCrop_ArkWhtRedR  OilCrop_ArkWhtRedR_RFD_lo  0.420060  0.630620  0.683979
# OilCrop_California  OilCrop_California_IRR_hi  0.095945  0.144038  0.156226
# ...                                       ...       ...       ...       ...
# OilCrop_UsaCstSE      OilCrop_UsaCstSE_RFD_lo  0.689340  1.034880  1.122440
# OilCrop_UsaPacNW      OilCrop_UsaPacNW_IRR_hi  0.006725  0.010096  0.010951
# OilCrop_UsaPacNW      OilCrop_UsaPacNW_IRR_lo  0.004483  0.006731  0.007300
# OilCrop_UsaPacNW      OilCrop_UsaPacNW_RFD_hi  0.008961  0.013452  0.014591
# OilCrop_UsaPacNW      OilCrop_UsaPacNW_RFD_lo  0.005974  0.008968  0.009727
#
#                         2015      2020      2025      2030      2035  \
# BasinName
# OilCrop_ArkWhtRedR  0.547850  0.580591  0.579773  0.566899  0.561160
# OilCrop_ArkWhtRedR  0.365233  0.380713  0.384014  0.382509  0.385373
# OilCrop_ArkWhtRedR  1.212000  1.382300  1.479500  1.541830  1.663680
# OilCrop_ArkWhtRedR  0.807998  0.880045  0.925038  0.957490  1.015830
# OilCrop_California  0.184553  0.233839  0.272495  0.308123  0.305413
# ...                      ...       ...       ...       ...       ...
# OilCrop_UsaCstSE    1.325960  1.432060  1.495660  1.541810  1.623630
# OilCrop_UsaPacNW    0.012936  0.016308  0.018721  0.020919  0.020775
# OilCrop_UsaPacNW    0.008624  0.009996  0.010976  0.011850  0.011888
# OilCrop_UsaPacNW    0.017236  0.019598  0.020490  0.021048  0.020780
# OilCrop_UsaPacNW    0.011491  0.012535  0.013050  0.013440  0.013421
#
#                         2040  ...      2060      2065      2070      2075  \
# BasinName                     ...
# OilCrop_ArkWhtRedR  0.559522  ...  0.633045  0.652468  0.657301  0.664224
# OilCrop_ArkWhtRedR  0.390247  ...  0.432243  0.441846  0.446069  0.450452
# OilCrop_ArkWhtRedR  1.794850  ...  2.357330  2.434350  2.454330  2.482980
# OilCrop_ArkWhtRedR  1.078390  ...  1.291430  1.318770  1.332120  1.345410
# OilCrop_California  0.307500  ...  0.350497  0.361619  0.364450  0.367333
# ...                      ...  ...       ...       ...       ...       ...
# OilCrop_UsaCstSE    1.713090  ...  2.033280  2.080360  2.105950  2.132260
# OilCrop_UsaPacNW    0.021262  ...  0.023942  0.024634  0.024810  0.025112
# OilCrop_UsaPacNW    0.012131  ...  0.013168  0.013425  0.013557  0.013702
# OilCrop_UsaPacNW    0.021173  ...  0.023565  0.024236  0.024412  0.024707
# OilCrop_UsaPacNW    0.013664  ...  0.014786  0.015085  0.015230  0.015396
#
#                         2080      2085      2090      2095      2100  Units
# BasinName
# OilCrop_ArkWhtRedR  0.672717  0.682130  0.689346  0.694206  0.697545     Mt
# OilCrop_ArkWhtRedR  0.454714  0.458612  0.461134  0.462226  0.462528     Mt
# OilCrop_ArkWhtRedR  2.518360  2.557790  2.587840  2.609110  2.624690     Mt
# OilCrop_ArkWhtRedR  1.357810  1.368700  1.375490  1.378150  1.378660     Mt
# OilCrop_California  0.370692  0.371175  0.360465  0.304199  0.300885     Mt
# ...                      ...       ...       ...       ...       ...    ...
# OilCrop_UsaCstSE    2.158160  2.183700  2.204070  2.217450  2.233150     Mt
# OilCrop_UsaPacNW    0.025474  0.025690  0.025869  0.025958  0.026060     Mt
# OilCrop_UsaPacNW    0.013842  0.013925  0.013987  0.014010  0.014044     Mt
# OilCrop_UsaPacNW    0.025059  0.025268  0.025442  0.025528  0.025627     Mt
# OilCrop_UsaPacNW    0.015558  0.015655  0.015728  0.015757  0.015797     Mt
#
# [72 rows x 23 columns]

# %%
ProductByBasin.loc['OilCrop_ArkWhtRedR',['Scenario', 2020,'Units']]
# Out:
#                                      Scenario      2020 Units
# BasinName
# OilCrop_ArkWhtRedR  OilCrop_ArkWhtRedR_IRR_hi  0.580591    Mt
# OilCrop_ArkWhtRedR  OilCrop_ArkWhtRedR_IRR_lo  0.380713    Mt
# OilCrop_ArkWhtRedR  OilCrop_ArkWhtRedR_RFD_hi  1.382300    Mt
# OilCrop_ArkWhtRedR  OilCrop_ArkWhtRedR_RFD_lo  0.880045    Mt

# %%
# Get each produciton by basinName, year, and technology
def GetBasinProduction(BName, BProduction, BYear, BTechnology):
    #  find the production by the basin name
    ProducutonByScens = BProduction.loc[BName,['Scenario',BYear, 'Units']]
    # find the production by technology
    ScenarioName = BName+BTechnology
    
    return ProducutonByScens.loc[ProducutonByScens['Scenario'] == ScenarioName,:]

Technologies = ['_IRR_hi','_IRR_lo','_RFD_hi','_RFD_lo']
BProdcution = GetBasinProduction('OilCrop_ArkWhtRedR', ProductByBasin, 2020,  Technologies[3])
BProdcution
# Out:
#                                      Scenario      2020 Units
# BasinName
# OilCrop_ArkWhtRedR  OilCrop_ArkWhtRedR_RFD_lo  0.880045    Mt

# %%
#assignment basin produciton to each eleavator
    # calculate number of elevators in the single basin
def GetEleProduciton(EleAndBasinList, BName, BProdcution):
    NumOfEles = EleAndBasinList['BasinName'].value_counts()
    NumOfEles = NumOfEles[NumOfEles.index==BName].values[0]

    #Production By Basin to ELevators
    YeildByEles = BProdcution.iloc[0,1] * 1000000 
    YeildByEle = YeildByEles / NumOfEles

    return NumOfEles, YeildByEles, round(YeildByEle, 2)

GetEleProduciton(EleAndBasin, 'OilCrop_ArkWhtRedR', BProdcution)
# Out:
# (26, 880045.0, 33847.88)

# %%
# Mian
import random
Basins = EleAndBasin.BasinName.unique()
Year = 2020
Technologies = ['_IRR_hi','_IRR_lo','_RFD_hi','_RFD_lo']
Technology = Technologies[3]

EleAndBasin['Ending'] = 0
EleAndBasin['EndingRate'] = 0
for basin in Basins:
    # Production of Basin
    BProdcution = GetBasinProduction(basin, ProductByBasin, Year, Technology)
    # Production by elevators
    EYield = GetEleProduciton(EleAndBasin, basin, BProdcution)

    #print(EYield)
    EleAndBasin.loc[EleAndBasin['BasinName']== basin, 'Production'] = EYield[2]
    
for index, row in EleAndBasin.iterrows():
    # Random Ending Stock [0,0.1]
    EndingRate = random.random() / 10
    EleAndBasin.iloc[index, 4] = EndingRate
    EleAndBasin.iloc[index, 3] = round( row['Production'] * EndingRate, 2) 

EleAndBasin
# Out:
#                                          Name          BasinName  Production  \
# 0                             Agency Rail LLC   OilCrop_MissppRN   157941.75
# 1                         Airial Construction   OilCrop_MissppRN   157941.75
# 2    Alliance Builders And Construction, Inc.   OilCrop_MissppRN   157941.75
# 3                      Artix Construction Inc   OilCrop_MissppRN   157941.75
# 4                Assumption Cooperative Grain   OilCrop_MissppRN   157941.75
# ..                                        ...                ...         ...
# 222                   Dakota Plains AG Center  OilCrop_MissouriR   156419.82
# 223              Farmers Cooperative Elevator   OilCrop_MissppRN   157941.75
# 224                      Harrold Grain Co LLC  OilCrop_MissouriR   156419.82
# 225          Madison Farmers Elevator Company  OilCrop_MissouriR   156419.82
# 226                Southeast Farmers Elevator  OilCrop_MissouriR   156419.82
#
#        Ending  EndingRate
# 0     9453.87    0.059857
# 1     2386.14    0.015108
# 2    14635.27    0.092662
# 3    14451.16    0.091497
# 4     3236.88    0.020494
# ..        ...         ...
# 222   5472.19    0.034984
# 223   5126.28    0.032457
# 224  13366.81    0.085455
# 225   2086.07    0.013336
# 226  15454.34    0.098800
#
# [227 rows x 5 columns]

# %%
EleAndBasin.to_csv('Outputs\ProductionByCountry_'+ str(Year) + Technology +'.csv', index=False)
