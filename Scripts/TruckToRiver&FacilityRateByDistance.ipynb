# %%
import pandas as pd
import numpy as np

distanceByTruck = pd.read_csv('Distance_CountryToLarger.csv',index_col = 0)

# %%
distanceByTruck['min_val'] = distanceByTruck.min(axis=1)
distanceByTruck.head()
# Out:
#                                           West River Transit  \
# Name
# Agency Rail LLC                                       885.89
# Airial Construction                                   820.99
# Alliance Builders And Construction, Inc.              832.76
# Artix Construction Inc                                819.26
# Assumption Cooperative Grain                          960.82
#
#                                           Vision Transportation of Elk River | Big Lake | Rogers | Zimmerman  \
# Name
# Agency Rail LLC                                                                      493.55
# Airial Construction                                                                  428.65
# Alliance Builders And Construction, Inc.                                             440.41
# Artix Construction Inc                                                               426.91
# Assumption Cooperative Grain                                                         568.48
#
#                                           River Cities Public Transit  \
# Name
# Agency Rail LLC                                                795.65
# Airial Construction                                            779.94
# Alliance Builders And Construction, Inc.                       791.71
# Artix Construction Inc                                         778.20
# Assumption Cooperative Grain                                   866.09
#
#                                           Two Rivers Transportation  \
# Name
# Agency Rail LLC                                              577.52
# Airial Construction                                          561.67
# Alliance Builders And Construction, Inc.                     573.43
# Artix Construction Inc                                       559.93
# Assumption Cooperative Grain                                 650.76
#
#                                           Blue Rivers Public Transportation  \
# Name
# Agency Rail LLC                                                      448.05
# Airial Construction                                                  487.29
# Alliance Builders And Construction, Inc.                             504.29
# Artix Construction Inc                                               497.56
# Assumption Cooperative Grain                                         422.89
#
#                                           Transport 360, LLC.  \
# Name
# Agency Rail LLC                                        360.41
# Airial Construction                                    493.69
# Alliance Builders And Construction, Inc.               496.02
# Artix Construction Inc                                 503.96
# Assumption Cooperative Grain                           335.26
#
#                                           Five Rivers Transport, LLC  \
# Name
# Agency Rail LLC                                               382.29
# Airial Construction                                           515.53
# Alliance Builders And Construction, Inc.                      517.90
# Artix Construction Inc                                        525.80
# Assumption Cooperative Grain                                  357.13
#
#                                           East Side River Transportation Inc  \
# Name
# Agency Rail LLC                                                       167.19
# Airial Construction                                                   291.00
# Alliance Builders And Construction, Inc.                              302.80
# Artix Construction Inc                                                302.22
# Assumption Cooperative Grain                                          114.61
#
#                                           River City Transportation  \
# Name
# Agency Rail LLC                                              157.16
# Airial Construction                                          126.48
# Alliance Builders And Construction, Inc.                     143.48
# Artix Construction Inc                                       136.75
# Assumption Cooperative Grain                                 220.03
#
#                                           River Transportation Co  min_val
# Name
# Agency Rail LLC                                            279.50   157.16
# Airial Construction                                        312.67   126.48
# Alliance Builders And Construction, Inc.                   292.62   143.48
# Artix Construction Inc                                     313.22   136.75
# Assumption Cooperative Grain                               281.38   114.61

# %%
def NormalizateData(OriginData, NMin, NMax, OMax, OMin):
    N = NMin + ((NMax-NMin)/(OMax-OMin))*(OriginData-OMin)
    return ("%.2f"  %N)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
OMax = distanceByTruck['min_val'].max()
OMin = distanceByTruck['min_val'].min()
Cost = []
for i in range(len(distanceByTruck['min_val'])):
    Cost.append(NormalizateData(distanceByTruck['min_val'].iloc[i], 3, 18, OMax, OMin))
Cost
# Out:
# ['8.78',
#  '7.60',
#  '8.26',
#  '8.00',
#  '7.14',
#  '4.52',
#  '6.34',
#  '7.71',
#  '8.02',
#  '8.26',
#  '8.50',
#  '10.44',
#  '8.35',
#  '7.95',
#  '6.94',
#  '6.89',
#  '11.01',
#  '10.99',
#  '7.79',
#  '8.13',
#  '9.70',
#  '8.07',
#  '8.15',
#  '8.26',
#  '7.82',
#  '8.28',
#  '7.59',
#  '6.84',
#  '5.57',
#  '8.05',
#  '7.18',
#  '8.96',
#  '7.99',
#  '8.93',
#  '8.26',
#  '6.05',
#  '6.05',
#  '4.86',
#  '6.69',
#  '8.43',
#  '7.79',
#  '7.88',
#  '8.68',
#  '8.00',
#  '6.22',
#  '3.68',
#  '10.35',
#  '7.07',
#  '8.61',
#  '4.40',
#  '9.17',
#  '7.85',
#  '9.75',
#  '6.67',
#  '7.51',
#  '8.26',
#  '6.48',
#  '7.13',
#  '8.24',
#  '3.56',
#  '6.21',
#  '8.14',
#  '8.45',
#  '7.73',
#  '10.26',
#  '9.58',
#  '10.38',
#  '11.44',
#  '10.82',
#  '10.99',
#  '9.15',
#  '9.57',
#  '6.80',
#  '10.90',
#  '10.07',
#  '4.35',
#  '9.80',
#  '8.19',
#  '6.64',
#  '9.98',
#  '7.72',
#  '9.30',
#  '9.90',
#  '7.87',
#  '7.75',
#  '7.87',
#  '8.93',
#  '6.63',
#  '10.27',
#  '10.27',
#  '9.57',
#  '8.72',
#  '8.05',
#  '6.54',
#  '7.68',
#  '5.53',
#  '13.02',
#  '14.85',
#  '6.19',
#  '4.32',
#  '8.55',
#  '6.79',
#  '6.74',
#  '3.19',
#  '10.44',
#  '9.59',
#  '7.63',
#  '6.34',
#  '10.44',
#  '6.93',
#  '4.52',
#  '8.05',
#  '9.05',
#  '8.22',
#  '8.68',
#  '6.60',
#  '6.34',
#  '7.29',
#  '6.62',
#  '6.62',
#  '6.69',
#  '7.37',
#  '16.42',
#  '16.42',
#  '6.60',
#  '7.12',
#  '4.98',
#  '9.78',
#  '10.22',
#  '4.03',
#  '8.08',
#  '7.45',
#  '10.52',
#  '6.45',
#  '12.91',
#  '10.99',
#  '9.28',
#  '9.79',
#  '10.12',
#  '9.57',
#  '5.90',
#  '8.52',
#  '9.20',
#  '9.83',
#  '6.08',
#  '4.13',
#  '3.14',
#  '3.00',
#  '3.30',
#  '7.28',
#  '3.30',
#  '3.00',
#  '3.00',
#  '4.43',
#  '4.92',
#  '3.00',
#  '6.70',
#  '4.89',
#  '7.67',
#  '3.30',
#  '6.12',
#  '3.73',
#  '9.90',
#  '10.90',
#  '9.50',
#  '9.95',
#  '11.45',
#  '10.08',
#  '6.67',
#  '4.12',
#  '9.73',
#  '11.70',
#  '5.35',
#  '7.05',
#  '9.78',
#  '11.97',
#  '9.40',
#  '6.62',
#  '10.54',
#  '9.81',
#  '11.65',
#  '11.45',
#  '5.62',
#  '9.90',
#  '6.62',
#  '4.30',
#  '10.19',
#  '8.03',
#  '9.77',
#  '17.18',
#  '15.96',
#  '9.16',
#  '9.95',
#  '5.27',
#  '10.98',
#  '11.28',
#  '10.23',
#  '16.49',
#  '12.91',
#  '17.50',
#  '15.96',
#  '3.65',
#  '15.69',
#  '3.14',
#  '7.32',
#  '3.22',
#  '17.18',
#  '3.50',
#  '9.77',
#  '16.03',
#  '14.56',
#  '10.27',
#  '13.19',
#  '10.41',
#  '11.18',
#  '10.27',
#  '13.94',
#  '12.86',
#  '3.50',
#  '18.00',
#  '10.27',
#  '15.96',
#  '4.02',
#  '9.54',
#  '4.05',
#  '6.98',
#  '5.44']

# %%
# write truck's cost to facility and Holding Cost of Country Elevators to file 
CostToFacility = distanceByTruck['min_val'].copy()
CostToFacility = CostToFacility.rename('Facility').to_frame()
CostToFacility['HoldingCost'] = 0

for i in range(CostToFacility.shape[0]):
    # assume this value is 1.5 times the cost to its larger elevators
    CostToFacility.iloc[i,0]= 1.5 * float(NormalizateData(distanceByTruck['min_val'].iloc[i], 3, 18, OMax, OMin))
    # assume this valeu is between 8 to 15
    CostToFacility.iloc[i,1] = round(np.random.uniform(8,15),2)

CostToFacility.to_csv('CostToFacility.csv')

# %%
# write trucks' cost from Country to Larger to file
TCostByDistance = distanceByTruck.copy()
TCostByDistance = TCostByDistance.drop('min_val',axis=1)

for i in range(TCostByDistance.shape[0]):
    for j in range(TCostByDistance.shape[1]):
        TCostByDistance.iloc[i,j] = NormalizateData(distanceByTruck.iloc[i,j], 3, 18, OMax, OMin)
    
TCostByDistance.to_csv('MileCostByTruck.csv')
